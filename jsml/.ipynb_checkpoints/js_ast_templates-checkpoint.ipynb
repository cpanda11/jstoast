# %%
import sqlite3
from sqlite3 import Error
import json
import random
import string
import pprint, pickle
import os

# %% [markdown]
# # class to handle database connections and queries

# %%
class sqliteDatabase():
    
    def __init__(self , url):
        self.conn = self.create_connection(url)
        
    def create_connection(self,db_file):
        """ create a database connection to the SQLite database
            specified by the db_file
        :param db_file: database file
        :return: Connection object or None
        """
        try:
            conn = sqlite3.connect(db_file)
            return conn
        except Error as e:
            print(e)

        return None


    def create_db(self):
        conn = self.conn
        c = conn.cursor()

        # Create table
        c.execute('''CREATE TABLE IF NOT EXISTS jta_scriptparse (
            id integer NOT NULL PRIMARY KEY AUTOINCREMENT,
            input_js text,
            output_ast text,
            comment bool NOT NULL,
            jsx bool NOT NULL,
            loc bool NOT NULL,
            range bool NOT NULL,
            tokens bool NOT NULL,
            tolerant bool NOT NULL
        );''')

        with open('jta_scriptparse_revise_modified.sql' , 'rb') as f:
        #     print(f.read().decode('utf-8').split(';'))
            for l in f.read().decode('utf-8').split('INSERT INTO')[1:]:
                l='INSERT INTO'+l
        #         print('ll :' , l)
                try:

                    # Insert a row of data
                    c.execute(l)

                    # Save (commit) the changes
                    conn.commit()

                    print("finish successfuly")
                except sqlite3.OperationalError as e:
                    print(e)
                    print('-'*50)
                    print(l)
                    break
                except Exception as e:
                    print(e)
                    print('-'*50)
                    print(l)
                    break



    def select_all_tasks(self):
        conn = self.conn
        """
        Query all rows in the tasks table
        :param conn: the Connection object
        :return:
        """
        cur = conn.cursor()
        cur.execute("SELECT * FROM jta_scriptparse")

        rows = cur.fetchall()

        return rows



    def select_row_by_id(self, id):
        conn = self.conn
        """
        Query tasks by priority
        :param conn: the Connection object
        :param priority:
        :return:
        """
        cur = conn.cursor()
        cur.execute("SELECT * FROM jta_scriptparse WHERE id=?", (id,))

        rows = cur.fetchall()

        return rows[0]

# %% [markdown]
# # class to learn templates from js ASTs :
# ## main functions:
# ### 1- learn_templates(database , convert_values):
# #### this function take a url to sqlite database that contains js ASTs and learn templates from it
# #### the convert_numbers parameter for changing variables values to static form
#
# ### 2- generate_ast(templates_model):
# #### this function create ast from random tempalte and set parameters values randomly

# %%
class js_templates():
    
    def __init__(self,reserved_words = './js_reserved_words.txt'):
        self.reserved_words_url = reserved_words

        
    def get_reserved_words(self):
        RESERVED_WORDS = []
        with open(self.reserved_words_url , 'r') as f:
            for l in f:
                RESERVED_WORDS.append(l.split('\n')[0])
        RESERVED_WORDS = set(RESERVED_WORDS)
        return RESERVED_WORDS

    def convert_template(self,inDict ,template_vars={} , conver_numbers = True):
        if isinstance(inDict, dict):
            for k in inDict.keys():
                inDict[k] = self.convert_template(inDict[k] ,template_vars , conver_numbers)

            if inDict.get('type')!= None and inDict.get('name')!= None:
                if inDict['type'] == 'Identifier':
#                         print("change var :" , inDict['id']['name'])
                    if inDict['name'] in self.get_reserved_words():
                        pass
                    elif inDict['name'] not in template_vars:
                        rand = 'I'+''.join(random.choices(string.ascii_uppercase + string.digits, k=10))
                        template_vars[inDict['name']] = rand
                        inDict['name'] = rand

                    else:
                        inDict['name'] = template_vars[inDict['name']]


            elif conver_numbers:
                if inDict.get('type')!= None and inDict.get('value')!= None and inDict.get('raw')!= None:
                    if inDict['type'] == "Literal":
                        temp = str(type(inDict['value']))
#                         if type(inDict['value']) == int:
#                             temp = str(float)
                        inDict['value'] = temp
                        inDict['raw'] = temp


        elif isinstance(inDict, list):
            for i in range(len(inDict)):
                inDict[i] = self.convert_template(inDict[i] ,template_vars ,conver_numbers)

        return inDict
    
    def merge_two_dicts(self,x, y):
        """Given two dicts, merge them into a new dict as a shallow copy."""
        for k in y:
#             print(k)
            if k in x:
                x[k].extend(y[k])
            else:
                x[k] = y[k]
        return x

    def get_types_templates(self ,inDict , all_type_ids):
        types = {}
        if isinstance(inDict, dict):
            if inDict.get('type'):
                if inDict.get('type') in all_type_ids:
                    if types.get(inDict.get('type')):
                        types[inDict.get('type')].append(inDict)
                    else:
                        types[inDict.get('type')] = [inDict]


            for k in inDict.keys():
                types = self.merge_two_dicts(types, self.get_types_templates(inDict[k],all_type_ids))

        elif isinstance(inDict, list):
            for i in range(len(inDict)):
                types = self.merge_two_dicts(types, self.get_types_templates(inDict[i],all_type_ids))

        return types



    def get_all_types_templates(self,templates , all_type_ids):
        database = "./jta_scriptparse_revise.db"

        all_typess = {}

        for row in templates:
            counter =0
            temp_ids = []
            row_ast = json.loads(row[1])

            temps = self.get_types_templates(row_ast , all_type_ids)

            all_typess = self.merge_two_dicts(all_typess , temps)


        return all_typess
    
    
    
    def get_ids_from_template(self,inDict):
        ids =[]
        if isinstance(inDict, dict):
            if inDict.get('type'):
                ids.append(inDict.get('type'))

            for k in inDict.keys():
                ids.extend(self.get_ids_from_template(inDict[k]))

        elif isinstance(inDict, list):
            for i in range(len(inDict)):
                ids.extend(self.get_ids_from_template(inDict[i]))

        return set(ids)
    
    
    def get_all_ast_ids(self,database = "./jta_scriptparse_revise.db"):
        
        
        data = sqliteDatabase(database)

        all_ids = []
        rows = data.select_all_tasks()
        for row in rows:
            row_ast = json.loads(row[2])
            tid = self.get_ids_from_template(row_ast)
            all_ids.extend(tid)
        return set(all_ids)





    def convert_all_templates(self,database ="./jta_scriptparse_revise.db" ,conver_numbers = True):

        all_tempaltes = []

        data = sqliteDatabase(database)
        print("Query all ...")
        rows = data.select_all_tasks()
        for row in rows:
            row_ast = json.loads(row[2])
            template = self.convert_template(row_ast ,template_vars={},conver_numbers=conver_numbers)
            all_tempaltes.append((row[0],json.dumps(template)))

        return all_tempaltes




    def generate_ast_template(self,inDict,template_vars={}):
        if isinstance(inDict, dict):
            for k in inDict.keys():
                inDict[k] = self.generate_ast_template(inDict[k],template_vars)
            

            if inDict.get('type')!= None and inDict.get('name')!= None:
                if inDict['type'] == 'Identifier':
#                         print("change var :" , inDict['id']['name'])
                    if inDict['name'] in self.get_reserved_words():
                        pass
        
                    elif inDict['name'] not in template_vars:
                        rand = 'I'+''.join(random.choices(string.ascii_uppercase + string.digits, k=10))
                        template_vars[inDict['name']] = rand
                        inDict['name'] = rand

                    else:
                        inDict['name'] = template_vars[inDict['name']]


            elif inDict.get('type')!= None and inDict.get('value')!= None and inDict.get('raw')!= None:
                if inDict['type'] == "Literal":
#                     print("change \t:",inDict['value'])
                    if inDict['value'] == str(float):
                        rand = random.uniform(1.0, 100.0)
                        inDict['value'] = rand
                        inDict['raw'] = str(rand)
                    
                    if inDict['value'] == str(int):
                        rand = random.randint(0,100)
                        inDict['value'] = rand
                        inDict['raw'] = str(rand)

                    elif inDict['value'] == str(str):
                        rand = ''.join(random.choices(string.ascii_uppercase + string.digits, k=5))
                        inDict['value'] = rand
                        inDict['raw'] = "\""+rand+"\""

                    elif inDict['value'] == str(bool):
                        rand = bool(random.getrandbits(1))
                        inDict['value'] = rand
                        inDict['raw'] = str(rand)


        elif isinstance(inDict, list):
            for i in range(len(inDict)):
                inDict[i] = self.generate_ast_template(inDict[i],template_vars)

        return inDict
    
    
    def generate_random_program (self,inDict):
    
        all_type_ids , all_types = [],{}
        with open('js_types_templates.pkl' , 'rb') as f:
            all_type_ids , all_types = pickle.load(f)
        if all_types == {}:
            print("error loading templates")
            return None

        if isinstance(inDict, dict):
            if inDict.get('body'):
                if isinstance(inDict['body'],list):
                    for i in range(len(inDict['body'])):
                        if isinstance(inDict['body'][i],dict):
                            if inDict['body'][i].get('type'):
                                if all_types.get(inDict['body'][i].get('type')):
                                    rand = random.randint(0 , len(all_types[inDict['body'][i].get('type')])-1)
                                    inDict['body'][i] = all_types[inDict['body'][i].get('type')][rand]

                                else:
                                    print("ERROR6")
                            else:
                                print("ERROR5")
                        else:
                            print("ERROR4")
                    return inDict
                else:
                    print("ERROR3")
            else:
                print("ERROR2")
        else:
            print("ERROR1")

        return None
    
    
    def learn_templates(self ,database ="./jta_scriptparse_revise.db" ,convert_values=False):
        if not os.path.isfile(database) :
            print("database not found !!!")
            return None
        templates = self.convert_all_templates(database,conver_numbers=convert_values)
        print('number of ASTs: \t' ,len([t[1] for t in templates]))
        print('number of program templates lerned: \t' ,len(set([t[1] for t in templates])))
        
        url = './js_program_templates.pkl'
        url2 = './js_types_templates.pkl'
        
        with open(url, 'wb') as f:
            pickle.dump(templates , f)
            
            
        print('-'*50)   
        print('\n')
        
        
        all_type_ids = self.get_all_ast_ids()
        all_types = self.get_all_types_templates(templates,all_type_ids)
                
        with open(url2 , 'wb') as f:
            pickle.dump((all_type_ids , all_types) , f)
        
        print("\n")
        
        print('number of types templates lerned: \t' ,len(all_types))
        for k in all_types:
            print(k,"\t" , len(all_types[k]))
        print('-'*50)   
        print('\n')
        
        print('number of reserved words :\t',len(self.get_reserved_words()))
        
        
        print('-'*50)   
        print('\n')
        print('learned model saved to: \n' ,url , "\n" , url2)
            
        
    def generate_ast(self,templates_model ='./js_templates.pkl'):
        templates = []
        
        
        if os.path.isfile(templates_model) :
            with open(templates_model, 'rb') as f:
                templates = pickle.load(f)
        else:
            print("model not found !!!")
            templates_model ='./js_templates.pkl'
            database ="./jta_scriptparse_revise.db"
            if os.path.isfile(database) :
                self.learn_templates(database =database ,convert_values=True)
            else:
                print("database not found !!!")
            
        index = random.randint(0, len(templates)-1)
        
        template = templates[index]
        
        templ = json.loads(template[1])
        rand_ast = self.generate_ast_template(self.generate_random_program(templ))
        
        return json.dumps(rand_ast)

# %%
jt = js_templates(reserved_words='js_reserved_words.txt')

# %%
jt.learn_templates(database ="./jta_scriptparse_revise.db" ,convert_values=True)
# Out:
# Query all ...

# %%
jt.generate_ast(templates_model ='./js_templates.pkl')

# %%
jt.generate_ast(templates_model ='./js_templates.pkl')

# %%
# jt.generate_ast(templates_model ='./js_templates.pkl')

# %%
# jt.generate_ast(templates_model ='./js_templates.pkl')

# %%
# jt.generate_ast(templates_model ='./js_templates.pkl')

# %% [markdown]
# # var i=0;

# %%
inDict = {
    "type": "Program",
    "body": [
        {
            "type": "VariableDeclaration",
            "declarations": [
                {
                    "type": "VariableDeclarator",
                    "id": {
                        "type": "Identifier",
                        "name": "i"
                    },
                    "init": {
                        "type": "Literal",
                        "value": 1,
                        "raw": "1"
                    }
                }
            ],
            "kind": "var"
        }
    ],
    "sourceType": "script"
}

# %% [markdown]
# ## 1- get template

# %%
t =jt.convert_template(inDict)
t

# %% [markdown]
# ## 2- generate random variable names and values

# %%
jt.generate_ast_template(t)

# %% [markdown]
# ## 3- change blocks of code

# %%
jt.generate_ast_template(jt.generate_random_program(t))

# %% [markdown]
# # function test(){
# # var i=4;
# # return i;
# # }

# %%
inDict = {
    "type": "Program",
    "body": [
        {
            "type": "FunctionDeclaration",
            "id": {
                "type": "Identifier",
                "name": "test"
            },
            "params": [],
            "body": {
                "type": "BlockStatement",
                "body": [
                    {
                        "type": "VariableDeclaration",
                        "declarations": [
                            {
                                "type": "VariableDeclarator",
                                "id": {
                                    "type": "Identifier",
                                    "name": "i"
                                },
                                "init": {
                                    "type": "Literal",
                                    "value": 5,
                                    "raw": "5"
                                }
                            }
                        ],
                        "kind": "var"
                    },
                    {
                        "type": "ReturnStatement",
                        "argument": {
                            "type": "Identifier",
                            "name": "i"
                        }
                    }
                ]
            },
            "generator": False,
            "expression": False,
            "async": False
        }
    ],
    "sourceType": "script"
}

# %% [markdown]
# ## 1- get template

# %%
t= jt.convert_template(inDict)
t
# Out:
# {'type': 'Program',
#  'body': [{'type': 'FunctionDeclaration',
#    'id': {'type': 'Identifier', 'name': 'test'},
#    'params': [],
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'VariableDeclaration',
#       'declarations': [{'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'IJLN0YE0Y48'},
#         'init': {'type': 'Literal',
#          'value': "<class 'int'>",
#          'raw': "<class 'int'>"}}],
#       'kind': 'var'},
#      {'type': 'ReturnStatement',
#       'argument': {'type': 'Identifier', 'name': 'IJLN0YE0Y48'}}]},
#    'generator': False,
#    'expression': False,
#    'async': False}],
#  'sourceType': 'script'}

# %% [markdown]
# ## 2- generate random variable names and values

# %%
jt.generate_ast_template(t)
# Out:
# {'type': 'Program',
#  'body': [{'type': 'FunctionDeclaration',
#    'id': {'type': 'Identifier', 'name': 'test'},
#    'params': [],
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'VariableDeclaration',
#       'declarations': [{'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'IB0VPS13G9C'},
#         'init': {'type': 'Literal', 'value': 30, 'raw': '30'}}],
#       'kind': 'var'},
#      {'type': 'ReturnStatement',
#       'argument': {'type': 'Identifier', 'name': 'IB0VPS13G9C'}}]},
#    'generator': False,
#    'expression': False,
#    'async': False}],
#  'sourceType': 'script'}

# %% [markdown]
# ## 3- change blocks of code

# %%
jt.generate_ast_template(jt.generate_random_program(t))
# Out:
# {'type': 'Program',
#  'body': [{'type': 'FunctionDeclaration',
#    'expression': False,
#    'async': False,
#    'id': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#    'params': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#     {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#     {'type': 'Identifier', 'name': 'I13JL7LDGHS'}],
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'VariableDeclaration',
#       'declarations': [{'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'IYXJQTXW90V'}},
#        {'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'IQ0LS753WKJ'}},
#        {'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'IOAVDEZ4415'}},
#        {'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'IKVITX3F1YO'}},
#        {'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'I5AVTW531OE'}}],
#       'kind': 'var'},
#      {'type': 'IfStatement',
#       'test': {'type': 'UnaryExpression',
#        'prefix': True,
#        'operator': '!',
#        'argument': {'type': 'Identifier', 'name': 'I9R6V4O2430'}},
#       'consequent': {'type': 'BlockStatement',
#        'body': [{'type': 'ReturnStatement',
#          'argument': {'type': 'Literal', 'value': True, 'raw': 'True'}}]}},
#      {'type': 'IfStatement',
#       'test': {'type': 'UnaryExpression',
#        'prefix': True,
#        'operator': '!',
#        'argument': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'}},
#       'consequent': {'type': 'BlockStatement',
#        'body': [{'type': 'ReturnStatement',
#          'argument': {'type': 'Literal', 'value': False, 'raw': 'False'}}]}},
#      {'type': 'IfStatement',
#       'test': {'type': 'UnaryExpression',
#        'prefix': True,
#        'operator': '!',
#        'argument': {'type': 'Identifier', 'name': 'I13JL7LDGHS'}},
#       'consequent': {'type': 'BlockStatement',
#        'body': [{'type': 'ExpressionStatement',
#          'expression': {'type': 'AssignmentExpression',
#           'operator': '=',
#           'left': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#           'right': {'type': 'ArrayExpression', 'elements': []}}}]}},
#      {'type': 'SwitchStatement',
#       'discriminant': {'type': 'MemberExpression',
#        'computed': False,
#        'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#        'property': {'type': 'Identifier', 'name': 'type'}},
#       'cases': [{'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'L6JST', 'raw': '"L6JST"'},
#         'consequent': [{'type': 'ReturnStatement',
#           'argument': {'type': 'Literal', 'value': True, 'raw': 'True'}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'KS49D', 'raw': '"KS49D"'},
#         'consequent': [{'type': 'ReturnStatement',
#           'argument': {'type': 'BinaryExpression',
#            'operator': '===',
#            'left': {'type': 'CallExpression',
#             'callee': {'type': 'MemberExpression',
#              'computed': False,
#              'object': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#               'property': {'type': 'Identifier', 'name': 'value'}},
#              'property': {'type': 'Identifier', 'name': 'toLowerCase'}},
#             'arguments': []},
#            'right': {'type': 'CallExpression',
#             'callee': {'type': 'MemberExpression',
#              'computed': False,
#              'object': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#               'property': {'type': 'Identifier', 'name': 'type'}},
#              'property': {'type': 'Identifier', 'name': 'toLowerCase'}},
#             'arguments': []}}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'XGIOE', 'raw': '"XGIOE"'},
#         'consequent': [{'type': 'ExpressionStatement',
#           'expression': {'type': 'AssignmentExpression',
#            'operator': '=',
#            'left': {'type': 'Identifier', 'name': 'IYXJQTXW90V'},
#            'right': {'type': 'CallExpression',
#             'callee': {'type': 'MemberExpression',
#              'computed': False,
#              'object': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#               'property': {'type': 'Identifier', 'name': 'name'}},
#              'property': {'type': 'Identifier', 'name': 'split'}},
#             'arguments': [{'type': 'Literal',
#               'value': 'JPJPO',
#               'raw': '"JPJPO"'}]}}},
#          {'type': 'ExpressionStatement',
#           'expression': {'type': 'AssignmentExpression',
#            'operator': '=',
#            'left': {'type': 'Identifier', 'name': 'IQ0LS753WKJ'},
#            'right': {'type': 'MemberExpression',
#             'computed': True,
#             'object': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#             'property': {'type': 'BinaryExpression',
#              'operator': '-',
#              'left': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'Identifier', 'name': 'IYXJQTXW90V'},
#               'property': {'type': 'Identifier', 'name': 'length'}},
#              'right': {'type': 'Literal', 'value': 14, 'raw': '14'}}}}},
#          {'type': 'ReturnStatement',
#           'argument': {'type': 'CallExpression',
#            'callee': {'type': 'Identifier', 'name': 'IWZMCJISI3A'},
#            'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#             {'type': 'Identifier', 'name': 'IQ0LS753WKJ'},
#             {'type': 'Identifier', 'name': 'IYXJQTXW90V'}]}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'KXYWG', 'raw': '"KXYWG"'},
#         'consequent': [{'type': 'ForStatement',
#           'init': {'type': 'SequenceExpression',
#            'expressions': [{'type': 'AssignmentExpression',
#              'operator': '=',
#              'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#              'right': {'type': 'Literal', 'value': 49, 'raw': '49'}},
#             {'type': 'AssignmentExpression',
#              'operator': '=',
#              'left': {'type': 'Identifier', 'name': 'IKVITX3F1YO'},
#              'right': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'ITLZ265TKJJ'}},
#               'property': {'type': 'Identifier', 'name': 'length'}}}]},
#           'test': {'type': 'BinaryExpression',
#            'operator': '<',
#            'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#            'right': {'type': 'Identifier', 'name': 'IKVITX3F1YO'}},
#           'update': {'type': 'UpdateExpression',
#            'operator': '++',
#            'argument': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#            'prefix': True},
#           'body': {'type': 'BlockStatement',
#            'body': [{'type': 'IfStatement',
#              'test': {'type': 'CallExpression',
#               'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#               'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                {'type': 'MemberExpression',
#                 'computed': True,
#                 'object': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                  'property': {'type': 'Identifier', 'name': 'ITLZ265TKJJ'}},
#                 'property': {'type': 'Identifier', 'name': 'IOAVDEZ4415'}},
#                {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]},
#              'consequent': {'type': 'BlockStatement',
#               'body': [{'type': 'ReturnStatement',
#                 'argument': {'type': 'Literal',
#                  'value': False,
#                  'raw': 'False'}}]}}]}},
#          {'type': 'ReturnStatement',
#           'argument': {'type': 'Literal', 'value': True, 'raw': 'True'}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'MY2CP', 'raw': '"MY2CP"'},
#         'consequent': [{'type': 'ForStatement',
#           'init': {'type': 'SequenceExpression',
#            'expressions': [{'type': 'AssignmentExpression',
#              'operator': '=',
#              'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#              'right': {'type': 'Literal', 'value': 71, 'raw': '71'}},
#             {'type': 'AssignmentExpression',
#              'operator': '=',
#              'left': {'type': 'Identifier', 'name': 'IKVITX3F1YO'},
#              'right': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'ITLZ265TKJJ'}},
#               'property': {'type': 'Identifier', 'name': 'length'}}}]},
#           'test': {'type': 'BinaryExpression',
#            'operator': '<',
#            'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#            'right': {'type': 'Identifier', 'name': 'IKVITX3F1YO'}},
#           'update': {'type': 'UpdateExpression',
#            'operator': '++',
#            'argument': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#            'prefix': True},
#           'body': {'type': 'BlockStatement',
#            'body': [{'type': 'IfStatement',
#              'test': {'type': 'UnaryExpression',
#               'prefix': True,
#               'operator': '!',
#               'argument': {'type': 'CallExpression',
#                'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#                'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                 {'type': 'MemberExpression',
#                  'computed': True,
#                  'object': {'type': 'MemberExpression',
#                   'computed': False,
#                   'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                   'property': {'type': 'Identifier', 'name': 'ITLZ265TKJJ'}},
#                  'property': {'type': 'Identifier', 'name': 'IOAVDEZ4415'}},
#                 {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]}},
#              'consequent': {'type': 'BlockStatement',
#               'body': [{'type': 'ReturnStatement',
#                 'argument': {'type': 'Literal',
#                  'value': True,
#                  'raw': 'True'}}]}}]}},
#          {'type': 'ReturnStatement',
#           'argument': {'type': 'Literal', 'value': False, 'raw': 'False'}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'HBU53', 'raw': '"HBU53"'},
#         'consequent': [{'type': 'ForStatement',
#           'init': {'type': 'SequenceExpression',
#            'expressions': [{'type': 'AssignmentExpression',
#              'operator': '=',
#              'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#              'right': {'type': 'Literal', 'value': 2, 'raw': '2'}},
#             {'type': 'AssignmentExpression',
#              'operator': '=',
#              'left': {'type': 'Identifier', 'name': 'IKVITX3F1YO'},
#              'right': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'ITLZ265TKJJ'}},
#               'property': {'type': 'Identifier', 'name': 'length'}}}]},
#           'test': {'type': 'BinaryExpression',
#            'operator': '<',
#            'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#            'right': {'type': 'Identifier', 'name': 'IKVITX3F1YO'}},
#           'update': {'type': 'UpdateExpression',
#            'operator': '++',
#            'argument': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#            'prefix': True},
#           'body': {'type': 'BlockStatement',
#            'body': [{'type': 'IfStatement',
#              'test': {'type': 'CallExpression',
#               'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#               'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                {'type': 'MemberExpression',
#                 'computed': True,
#                 'object': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                  'property': {'type': 'Identifier', 'name': 'ITLZ265TKJJ'}},
#                 'property': {'type': 'Identifier', 'name': 'IOAVDEZ4415'}},
#                {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]},
#              'consequent': {'type': 'BlockStatement',
#               'body': [{'type': 'ReturnStatement',
#                 'argument': {'type': 'Literal',
#                  'value': True,
#                  'raw': 'True'}}]}}]}},
#          {'type': 'ReturnStatement',
#           'argument': {'type': 'Literal', 'value': False, 'raw': 'False'}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': '4O78P', 'raw': '"4O78P"'},
#         'consequent': [{'type': 'VariableDeclaration',
#           'declarations': [{'type': 'VariableDeclarator',
#             'id': {'type': 'Identifier', 'name': 'IVH08WKSGWT'}},
#            {'type': 'VariableDeclarator',
#             'id': {'type': 'Identifier', 'name': 'IIXDQG2NT5Q'},
#             'init': {'type': 'ArrayExpression', 'elements': []}}],
#           'kind': 'var'},
#          {'type': 'ForStatement',
#           'init': {'type': 'SequenceExpression',
#            'expressions': [{'type': 'AssignmentExpression',
#              'operator': '=',
#              'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#              'right': {'type': 'Literal', 'value': 22, 'raw': '22'}},
#             {'type': 'AssignmentExpression',
#              'operator': '=',
#              'left': {'type': 'Identifier', 'name': 'IKVITX3F1YO'},
#              'right': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'ITLZ265TKJJ'}},
#               'property': {'type': 'Identifier', 'name': 'length'}}}]},
#           'test': {'type': 'BinaryExpression',
#            'operator': '<',
#            'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#            'right': {'type': 'Identifier', 'name': 'IKVITX3F1YO'}},
#           'update': {'type': 'UpdateExpression',
#            'operator': '++',
#            'argument': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#            'prefix': True},
#           'body': {'type': 'BlockStatement',
#            'body': [{'type': 'ExpressionStatement',
#              'expression': {'type': 'AssignmentExpression',
#               'operator': '=',
#               'left': {'type': 'Identifier', 'name': 'IVH08WKSGWT'},
#               'right': {'type': 'ArrayExpression', 'elements': []}}},
#             {'type': 'ExpressionStatement',
#              'expression': {'type': 'CallExpression',
#               'callee': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'IKJ09DPX7KP'},
#                'property': {'type': 'Identifier', 'name': 'IEY1W45U24U'}},
#               'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                {'type': 'ObjectExpression',
#                 'properties': [{'type': 'Property',
#                   'key': {'type': 'Identifier', 'name': 'IRUXDITWP9J'},
#                   'computed': False,
#                   'value': {'type': 'FunctionExpression',
#                    'expression': False,
#                    'async': False,
#                    'params': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                     {'type': 'Identifier', 'name': 'parent'}],
#                    'body': {'type': 'BlockStatement',
#                     'body': [{'type': 'IfStatement',
#                       'test': {'type': 'BinaryExpression',
#                        'operator': '!=',
#                        'left': {'type': 'Identifier', 'name': 'parent'},
#                        'right': {'type': 'Literal', 'raw': 'null'}},
#                       'consequent': {'type': 'BlockStatement',
#                        'body': [{'type': 'ExpressionStatement',
#                          'expression': {'type': 'CallExpression',
#                           'callee': {'type': 'MemberExpression',
#                            'computed': False,
#                            'object': {'type': 'Identifier',
#                             'name': 'IVH08WKSGWT'},
#                            'property': {'type': 'Identifier',
#                             'name': 'unshift'}},
#                           'arguments': [{'type': 'Identifier',
#                             'name': 'parent'}]}}]}},
#                      {'type': 'IfStatement',
#                       'test': {'type': 'CallExpression',
#                        'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#                        'arguments': [{'type': 'Identifier',
#                          'name': 'I6OWV3GP6YE'},
#                         {'type': 'MemberExpression',
#                          'computed': True,
#                          'object': {'type': 'MemberExpression',
#                           'computed': False,
#                           'object': {'type': 'Identifier',
#                            'name': 'I9R6V4O2430'},
#                           'property': {'type': 'Identifier',
#                            'name': 'ITLZ265TKJJ'}},
#                          'property': {'type': 'Identifier',
#                           'name': 'IOAVDEZ4415'}},
#                         {'type': 'Identifier', 'name': 'IVH08WKSGWT'}]},
#                       'consequent': {'type': 'BlockStatement',
#                        'body': [{'type': 'ExpressionStatement',
#                          'expression': {'type': 'CallExpression',
#                           'callee': {'type': 'MemberExpression',
#                            'computed': False,
#                            'object': {'type': 'Identifier',
#                             'name': 'IIXDQG2NT5Q'},
#                            'property': {'type': 'Identifier', 'name': 'push'}},
#                           'arguments': [{'type': 'Identifier',
#                             'name': 'I6OWV3GP6YE'}]}}]}}]},
#                    'generator': False},
#                   'kind': 'init',
#                   'method': False,
#                   'shorthand': False},
#                  {'type': 'Property',
#                   'key': {'type': 'Identifier', 'name': 'IG08AU3D0AD'},
#                   'computed': False,
#                   'value': {'type': 'FunctionExpression',
#                    'expression': False,
#                    'async': False,
#                    'params': [],
#                    'body': {'type': 'BlockStatement',
#                     'body': [{'type': 'ExpressionStatement',
#                       'expression': {'type': 'CallExpression',
#                        'callee': {'type': 'MemberExpression',
#                         'computed': False,
#                         'object': {'type': 'Identifier',
#                          'name': 'IVH08WKSGWT'},
#                         'property': {'type': 'Identifier', 'name': 'shift'}},
#                        'arguments': []}}]},
#                    'generator': False},
#                   'kind': 'init',
#                   'method': False,
#                   'shorthand': False}]}]}}]}},
#          {'type': 'ReturnStatement',
#           'argument': {'type': 'BinaryExpression',
#            'operator': '!==',
#            'left': {'type': 'MemberExpression',
#             'computed': False,
#             'object': {'type': 'Identifier', 'name': 'IIXDQG2NT5Q'},
#             'property': {'type': 'Identifier', 'name': 'length'}},
#            'right': {'type': 'Literal', 'value': 80, 'raw': '80'}}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'TRQ31', 'raw': '"TRQ31"'},
#         'consequent': [{'type': 'IfStatement',
#           'test': {'type': 'CallExpression',
#            'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#            'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#             {'type': 'MemberExpression',
#              'computed': False,
#              'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#              'property': {'type': 'Identifier', 'name': 'right'}},
#             {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]},
#           'consequent': {'type': 'BlockStatement',
#            'body': [{'type': 'ReturnStatement',
#              'argument': {'type': 'CallExpression',
#               'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#               'arguments': [{'type': 'MemberExpression',
#                 'computed': True,
#                 'object': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#                 'property': {'type': 'Literal', 'value': 34, 'raw': '34'}},
#                {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                 'property': {'type': 'Identifier', 'name': 'left'}},
#                {'type': 'CallExpression',
#                 'callee': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#                  'property': {'type': 'Identifier', 'name': 'slice'}},
#                 'arguments': [{'type': 'Literal',
#                   'value': 67,
#                   'raw': '67'}]}]}}]}},
#          {'type': 'ReturnStatement',
#           'argument': {'type': 'Literal', 'value': False, 'raw': 'False'}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'VLJCB', 'raw': '"VLJCB"'},
#         'consequent': [{'type': 'IfStatement',
#           'test': {'type': 'CallExpression',
#            'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#            'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#             {'type': 'MemberExpression',
#              'computed': False,
#              'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#              'property': {'type': 'Identifier', 'name': 'right'}},
#             {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]},
#           'consequent': {'type': 'BlockStatement',
#            'body': [{'type': 'ForStatement',
#              'init': {'type': 'SequenceExpression',
#               'expressions': [{'type': 'AssignmentExpression',
#                 'operator': '=',
#                 'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#                 'right': {'type': 'Literal', 'value': 53, 'raw': '53'}},
#                {'type': 'AssignmentExpression',
#                 'operator': '=',
#                 'left': {'type': 'Identifier', 'name': 'IKVITX3F1YO'},
#                 'right': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#                  'property': {'type': 'Identifier', 'name': 'length'}}}]},
#              'test': {'type': 'BinaryExpression',
#               'operator': '<',
#               'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#               'right': {'type': 'Identifier', 'name': 'IKVITX3F1YO'}},
#              'update': {'type': 'UpdateExpression',
#               'operator': '++',
#               'argument': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#               'prefix': True},
#              'body': {'type': 'BlockStatement',
#               'body': [{'type': 'IfStatement',
#                 'test': {'type': 'CallExpression',
#                  'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#                  'arguments': [{'type': 'MemberExpression',
#                    'computed': True,
#                    'object': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#                    'property': {'type': 'Identifier', 'name': 'IOAVDEZ4415'}},
#                   {'type': 'MemberExpression',
#                    'computed': False,
#                    'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                    'property': {'type': 'Identifier', 'name': 'left'}},
#                   {'type': 'CallExpression',
#                    'callee': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#                     'property': {'type': 'Identifier', 'name': 'slice'}},
#                    'arguments': [{'type': 'BinaryExpression',
#                      'operator': '+',
#                      'left': {'type': 'Identifier', 'name': 'IOAVDEZ4415'},
#                      'right': {'type': 'Literal',
#                       'value': 39,
#                       'raw': '39'}}]}]},
#                 'consequent': {'type': 'BlockStatement',
#                  'body': [{'type': 'ReturnStatement',
#                    'argument': {'type': 'Literal',
#                     'value': True,
#                     'raw': 'True'}}]}}]}}]}},
#          {'type': 'ReturnStatement',
#           'argument': {'type': 'Literal', 'value': True, 'raw': 'True'}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'T8ZRP', 'raw': '"T8ZRP"'},
#         'consequent': [{'type': 'ExpressionStatement',
#           'expression': {'type': 'AssignmentExpression',
#            'operator': '=',
#            'left': {'type': 'Identifier', 'name': 'I5AVTW531OE'},
#            'right': {'type': 'CallExpression',
#             'callee': {'type': 'Identifier', 'name': 'I9ULXMQAE15'},
#             'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#              {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#               'property': {'type': 'Identifier', 'name': 'name'}}]}}},
#          {'type': 'SwitchStatement',
#           'discriminant': {'type': 'MemberExpression',
#            'computed': False,
#            'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#            'property': {'type': 'Identifier', 'name': 'I9HMID5K44H'}},
#           'cases': [{'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'raw': 'null'},
#             'consequent': []},
#            {'type': 'SwitchCase',
#             'test': {'type': 'UnaryExpression',
#              'prefix': True,
#              'operator': 'void',
#              'argument': {'type': 'Literal', 'value': 25, 'raw': '25'}},
#             'consequent': [{'type': 'ReturnStatement',
#               'argument': {'type': 'BinaryExpression',
#                'operator': '!=',
#                'left': {'type': 'Identifier', 'name': 'I5AVTW531OE'},
#                'right': {'type': 'Literal', 'raw': 'null'}}}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'ZQ1F4', 'raw': '"ZQ1F4"'},
#             'consequent': [{'type': 'SwitchStatement',
#               'discriminant': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                 'property': {'type': 'Identifier', 'name': 'value'}},
#                'property': {'type': 'Identifier', 'name': 'type'}},
#               'cases': [{'type': 'SwitchCase',
#                 'test': {'type': 'Literal',
#                  'value': '0FBFL',
#                  'raw': '"0FBFL"'},
#                 'consequent': [{'type': 'ReturnStatement',
#                   'argument': {'type': 'LogicalExpression',
#                    'operator': '&&',
#                    'left': {'type': 'BinaryExpression',
#                     'operator': '===',
#                     'left': {'type': 'UnaryExpression',
#                      'prefix': True,
#                      'operator': 'typeof',
#                      'argument': {'type': 'Identifier',
#                       'name': 'I5AVTW531OE'}},
#                     'right': {'type': 'Literal',
#                      'value': '9V874',
#                      'raw': '"9V874"'}},
#                    'right': {'type': 'CallExpression',
#                     'callee': {'type': 'MemberExpression',
#                      'computed': False,
#                      'object': {'type': 'MemberExpression',
#                       'computed': False,
#                       'object': {'type': 'MemberExpression',
#                        'computed': False,
#                        'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                        'property': {'type': 'Identifier', 'name': 'value'}},
#                       'property': {'type': 'Identifier', 'name': 'value'}},
#                      'property': {'type': 'Identifier', 'name': 'test'}},
#                     'arguments': [{'type': 'Identifier',
#                       'name': 'I5AVTW531OE'}]}}}]},
#                {'type': 'SwitchCase',
#                 'test': {'type': 'Literal',
#                  'value': 'IGY7I',
#                  'raw': '"IGY7I"'},
#                 'consequent': [{'type': 'ReturnStatement',
#                   'argument': {'type': 'BinaryExpression',
#                    'operator': '===',
#                    'left': {'type': 'BinaryExpression',
#                     'operator': '+',
#                     'left': {'type': 'Literal',
#                      'value': 'ZFJ4N',
#                      'raw': '"ZFJ4N"'},
#                     'right': {'type': 'MemberExpression',
#                      'computed': False,
#                      'object': {'type': 'MemberExpression',
#                       'computed': False,
#                       'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                       'property': {'type': 'Identifier', 'name': 'value'}},
#                      'property': {'type': 'Identifier', 'name': 'value'}}},
#                    'right': {'type': 'BinaryExpression',
#                     'operator': '+',
#                     'left': {'type': 'Literal',
#                      'value': 'GT6DN',
#                      'raw': '"GT6DN"'},
#                     'right': {'type': 'Identifier',
#                      'name': 'I5AVTW531OE'}}}}]},
#                {'type': 'SwitchCase',
#                 'test': {'type': 'Literal',
#                  'value': 'KD9NU',
#                  'raw': '"KD9NU"'},
#                 'consequent': [{'type': 'ReturnStatement',
#                   'argument': {'type': 'BinaryExpression',
#                    'operator': '===',
#                    'left': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'MemberExpression',
#                      'computed': False,
#                      'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                      'property': {'type': 'Identifier', 'name': 'value'}},
#                     'property': {'type': 'Identifier', 'name': 'value'}},
#                    'right': {'type': 'UnaryExpression',
#                     'prefix': True,
#                     'operator': 'typeof',
#                     'argument': {'type': 'Identifier',
#                      'name': 'I5AVTW531OE'}}}}]}]}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'ES6VX', 'raw': '"ES6VX"'},
#             'consequent': [{'type': 'SwitchStatement',
#               'discriminant': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                 'property': {'type': 'Identifier', 'name': 'value'}},
#                'property': {'type': 'Identifier', 'name': 'type'}},
#               'cases': [{'type': 'SwitchCase',
#                 'test': {'type': 'Literal',
#                  'value': '8QSW9',
#                  'raw': '"8QSW9"'},
#                 'consequent': [{'type': 'ReturnStatement',
#                   'argument': {'type': 'UnaryExpression',
#                    'prefix': True,
#                    'operator': '!',
#                    'argument': {'type': 'CallExpression',
#                     'callee': {'type': 'MemberExpression',
#                      'computed': False,
#                      'object': {'type': 'MemberExpression',
#                       'computed': False,
#                       'object': {'type': 'MemberExpression',
#                        'computed': False,
#                        'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                        'property': {'type': 'Identifier', 'name': 'value'}},
#                       'property': {'type': 'Identifier', 'name': 'value'}},
#                      'property': {'type': 'Identifier', 'name': 'test'}},
#                     'arguments': [{'type': 'Identifier',
#                       'name': 'I5AVTW531OE'}]}}}]},
#                {'type': 'SwitchCase',
#                 'test': {'type': 'Literal',
#                  'value': '04S2S',
#                  'raw': '"04S2S"'},
#                 'consequent': [{'type': 'ReturnStatement',
#                   'argument': {'type': 'BinaryExpression',
#                    'operator': '!==',
#                    'left': {'type': 'BinaryExpression',
#                     'operator': '+',
#                     'left': {'type': 'Literal',
#                      'value': 'CH974',
#                      'raw': '"CH974"'},
#                     'right': {'type': 'MemberExpression',
#                      'computed': False,
#                      'object': {'type': 'MemberExpression',
#                       'computed': False,
#                       'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                       'property': {'type': 'Identifier', 'name': 'value'}},
#                      'property': {'type': 'Identifier', 'name': 'value'}}},
#                    'right': {'type': 'BinaryExpression',
#                     'operator': '+',
#                     'left': {'type': 'Literal',
#                      'value': 'RCTTA',
#                      'raw': '"RCTTA"'},
#                     'right': {'type': 'Identifier',
#                      'name': 'I5AVTW531OE'}}}}]},
#                {'type': 'SwitchCase',
#                 'test': {'type': 'Literal',
#                  'value': 'FVLK3',
#                  'raw': '"FVLK3"'},
#                 'consequent': [{'type': 'ReturnStatement',
#                   'argument': {'type': 'BinaryExpression',
#                    'operator': '!==',
#                    'left': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'MemberExpression',
#                      'computed': False,
#                      'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                      'property': {'type': 'Identifier', 'name': 'value'}},
#                     'property': {'type': 'Identifier', 'name': 'value'}},
#                    'right': {'type': 'UnaryExpression',
#                     'prefix': True,
#                     'operator': 'typeof',
#                     'argument': {'type': 'Identifier',
#                      'name': 'I5AVTW531OE'}}}}]}]}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'VI5XB', 'raw': '"VI5XB"'},
#             'consequent': [{'type': 'ReturnStatement',
#               'argument': {'type': 'BinaryExpression',
#                'operator': '<=',
#                'left': {'type': 'Identifier', 'name': 'I5AVTW531OE'},
#                'right': {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                  'property': {'type': 'Identifier', 'name': 'value'}},
#                 'property': {'type': 'Identifier', 'name': 'value'}}}}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'KIXP4', 'raw': '"KIXP4"'},
#             'consequent': [{'type': 'ReturnStatement',
#               'argument': {'type': 'BinaryExpression',
#                'operator': '<',
#                'left': {'type': 'Identifier', 'name': 'I5AVTW531OE'},
#                'right': {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                  'property': {'type': 'Identifier', 'name': 'value'}},
#                 'property': {'type': 'Identifier', 'name': 'value'}}}}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'P7IMH', 'raw': '"P7IMH"'},
#             'consequent': [{'type': 'ReturnStatement',
#               'argument': {'type': 'BinaryExpression',
#                'operator': '>',
#                'left': {'type': 'Identifier', 'name': 'I5AVTW531OE'},
#                'right': {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                  'property': {'type': 'Identifier', 'name': 'value'}},
#                 'property': {'type': 'Identifier', 'name': 'value'}}}}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'SBQQG', 'raw': '"SBQQG"'},
#             'consequent': [{'type': 'ReturnStatement',
#               'argument': {'type': 'BinaryExpression',
#                'operator': '>=',
#                'left': {'type': 'Identifier', 'name': 'I5AVTW531OE'},
#                'right': {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                  'property': {'type': 'Identifier', 'name': 'value'}},
#                 'property': {'type': 'Identifier', 'name': 'value'}}}}]}]}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': '3KNHZ', 'raw': '"3KNHZ"'},
#         'consequent': [{'type': 'ReturnStatement',
#           'argument': {'type': 'LogicalExpression',
#            'operator': '||',
#            'left': {'type': 'LogicalExpression',
#             'operator': '&&',
#             'left': {'type': 'CallExpression',
#              'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#              'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#               {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'right'}},
#               {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]},
#             'right': {'type': 'CallExpression',
#              'callee': {'type': 'Identifier', 'name': 'IK27W5ZKD6Z'},
#              'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#               {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'left'}},
#               {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#               {'type': 'Identifier', 'name': 'I6B7P18HY7C'}]}},
#            'right': {'type': 'LogicalExpression',
#             'operator': '&&',
#             'left': {'type': 'LogicalExpression',
#              'operator': '&&',
#              'left': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'left'}},
#               'property': {'type': 'Identifier', 'name': 'IAPN0MZLAGQ'}},
#              'right': {'type': 'CallExpression',
#               'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#               'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                 'property': {'type': 'Identifier', 'name': 'left'}},
#                {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]}},
#             'right': {'type': 'CallExpression',
#              'callee': {'type': 'Identifier', 'name': 'IK27W5ZKD6Z'},
#              'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#               {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'right'}},
#               {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#               {'type': 'Identifier', 'name': 'I3NMIMPRIKL'}]}}}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': '0PV9B', 'raw': '"0PV9B"'},
#         'consequent': [{'type': 'ReturnStatement',
#           'argument': {'type': 'LogicalExpression',
#            'operator': '||',
#            'left': {'type': 'LogicalExpression',
#             'operator': '&&',
#             'left': {'type': 'CallExpression',
#              'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#              'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#               {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'right'}},
#               {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]},
#             'right': {'type': 'CallExpression',
#              'callee': {'type': 'Identifier', 'name': 'IFRLAN8F57D'},
#              'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#               {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'left'}},
#               {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#               {'type': 'Identifier', 'name': 'I6B7P18HY7C'}]}},
#            'right': {'type': 'LogicalExpression',
#             'operator': '&&',
#             'left': {'type': 'LogicalExpression',
#              'operator': '&&',
#              'left': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'right'}},
#               'property': {'type': 'Identifier', 'name': 'IAPN0MZLAGQ'}},
#              'right': {'type': 'CallExpression',
#               'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#               'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                {'type': 'MemberExpression',
#                 'computed': False,
#                 'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                 'property': {'type': 'Identifier', 'name': 'left'}},
#                {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]}},
#             'right': {'type': 'CallExpression',
#              'callee': {'type': 'Identifier', 'name': 'IFRLAN8F57D'},
#              'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#               {'type': 'MemberExpression',
#                'computed': False,
#                'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                'property': {'type': 'Identifier', 'name': 'right'}},
#               {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#               {'type': 'Identifier', 'name': 'I3NMIMPRIKL'}]}}}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'EG0BP', 'raw': '"EG0BP"'},
#         'consequent': [{'type': 'ReturnStatement',
#           'argument': {'type': 'LogicalExpression',
#            'operator': '&&',
#            'left': {'type': 'CallExpression',
#             'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#             'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#              {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#               'property': {'type': 'Identifier', 'name': 'right'}},
#              {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]},
#            'right': {'type': 'CallExpression',
#             'callee': {'type': 'Identifier', 'name': 'IYGR0BEDNS7'},
#             'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#              {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#              {'type': 'FunctionExpression',
#               'expression': False,
#               'async': False,
#               'params': [{'type': 'Identifier', 'name': 'length'}],
#               'body': {'type': 'BlockStatement',
#                'body': [{'type': 'ReturnStatement',
#                  'argument': {'type': 'BinaryExpression',
#                   'operator': '-',
#                   'left': {'type': 'MemberExpression',
#                    'computed': False,
#                    'object': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                     'property': {'type': 'Identifier', 'name': 'index'}},
#                    'property': {'type': 'Identifier', 'name': 'value'}},
#                   'right': {'type': 'Literal', 'value': 74, 'raw': '74'}}}]},
#               'generator': False}]}}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': 'E7PQV', 'raw': '"E7PQV"'},
#         'consequent': [{'type': 'ReturnStatement',
#           'argument': {'type': 'LogicalExpression',
#            'operator': '&&',
#            'left': {'type': 'CallExpression',
#             'callee': {'type': 'Identifier', 'name': 'I0BNQK508NC'},
#             'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#              {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#               'property': {'type': 'Identifier', 'name': 'right'}},
#              {'type': 'Identifier', 'name': 'I13JL7LDGHS'}]},
#            'right': {'type': 'CallExpression',
#             'callee': {'type': 'Identifier', 'name': 'IYGR0BEDNS7'},
#             'arguments': [{'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#              {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#              {'type': 'FunctionExpression',
#               'expression': False,
#               'async': False,
#               'params': [{'type': 'Identifier', 'name': 'length'}],
#               'body': {'type': 'BlockStatement',
#                'body': [{'type': 'ReturnStatement',
#                  'argument': {'type': 'BinaryExpression',
#                   'operator': '-',
#                   'left': {'type': 'Identifier', 'name': 'length'},
#                   'right': {'type': 'MemberExpression',
#                    'computed': False,
#                    'object': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#                     'property': {'type': 'Identifier', 'name': 'index'}},
#                    'property': {'type': 'Identifier', 'name': 'value'}}}}]},
#               'generator': False}]}}}]},
#        {'type': 'SwitchCase',
#         'test': {'type': 'Literal', 'value': '6AYHM', 'raw': '"6AYHM"'},
#         'consequent': [{'type': 'IfStatement',
#           'test': {'type': 'UnaryExpression',
#            'prefix': True,
#            'operator': '!',
#            'argument': {'type': 'MemberExpression',
#             'computed': False,
#             'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#             'property': {'type': 'Identifier', 'name': 'type'}}},
#           'consequent': {'type': 'ReturnStatement',
#            'argument': {'type': 'Literal', 'value': False, 'raw': 'False'}}},
#          {'type': 'SwitchStatement',
#           'discriminant': {'type': 'CallExpression',
#            'callee': {'type': 'MemberExpression',
#             'computed': False,
#             'object': {'type': 'MemberExpression',
#              'computed': False,
#              'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#              'property': {'type': 'Identifier', 'name': 'name'}},
#             'property': {'type': 'Identifier', 'name': 'toLowerCase'}},
#            'arguments': []},
#           'cases': [{'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': '1PIRW', 'raw': '"1PIRW"'},
#             'consequent': [{'type': 'IfStatement',
#               'test': {'type': 'BinaryExpression',
#                'operator': '===',
#                'left': {'type': 'CallExpression',
#                 'callee': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'MemberExpression',
#                   'computed': False,
#                   'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                   'property': {'type': 'Identifier', 'name': 'type'}},
#                  'property': {'type': 'Identifier', 'name': 'slice'}},
#                 'arguments': [{'type': 'UnaryExpression',
#                   'prefix': True,
#                   'operator': '-',
#                   'argument': {'type': 'Literal', 'value': 27, 'raw': '27'}}]},
#                'right': {'type': 'Literal',
#                 'value': '2DGB1',
#                 'raw': '"2DGB1"'}},
#               'consequent': {'type': 'ReturnStatement',
#                'argument': {'type': 'Literal',
#                 'value': True,
#                 'raw': 'True'}}}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'JSRVL', 'raw': '"JSRVL"'},
#             'consequent': [{'type': 'ReturnStatement',
#               'argument': {'type': 'BinaryExpression',
#                'operator': '===',
#                'left': {'type': 'CallExpression',
#                 'callee': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'MemberExpression',
#                   'computed': False,
#                   'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                   'property': {'type': 'Identifier', 'name': 'type'}},
#                  'property': {'type': 'Identifier', 'name': 'slice'}},
#                 'arguments': [{'type': 'UnaryExpression',
#                   'prefix': True,
#                   'operator': '-',
#                   'argument': {'type': 'Literal', 'value': 42, 'raw': '42'}}]},
#                'right': {'type': 'Literal',
#                 'value': 'ZKEK4',
#                 'raw': '"ZKEK4"'}}}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': '3QZHO', 'raw': '"3QZHO"'},
#             'consequent': [{'type': 'IfStatement',
#               'test': {'type': 'BinaryExpression',
#                'operator': '===',
#                'left': {'type': 'CallExpression',
#                 'callee': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'MemberExpression',
#                   'computed': False,
#                   'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                   'property': {'type': 'Identifier', 'name': 'type'}},
#                  'property': {'type': 'Identifier', 'name': 'slice'}},
#                 'arguments': [{'type': 'UnaryExpression',
#                   'prefix': True,
#                   'operator': '-',
#                   'argument': {'type': 'Literal', 'value': 85, 'raw': '85'}}]},
#                'right': {'type': 'Literal',
#                 'value': 'I09X6',
#                 'raw': '"I09X6"'}},
#               'consequent': {'type': 'ReturnStatement',
#                'argument': {'type': 'Literal',
#                 'value': False,
#                 'raw': 'False'}}}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'P4GKO', 'raw': '"P4GKO"'},
#             'consequent': [{'type': 'ReturnStatement',
#               'argument': {'type': 'LogicalExpression',
#                'operator': '||',
#                'left': {'type': 'LogicalExpression',
#                 'operator': '||',
#                 'left': {'type': 'LogicalExpression',
#                  'operator': '||',
#                  'left': {'type': 'BinaryExpression',
#                   'operator': '===',
#                   'left': {'type': 'CallExpression',
#                    'callee': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'MemberExpression',
#                      'computed': False,
#                      'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                      'property': {'type': 'Identifier', 'name': 'type'}},
#                     'property': {'type': 'Identifier', 'name': 'slice'}},
#                    'arguments': [{'type': 'UnaryExpression',
#                      'prefix': True,
#                      'operator': '-',
#                      'argument': {'type': 'Literal',
#                       'value': 67,
#                       'raw': '67'}}]},
#                   'right': {'type': 'Literal',
#                    'value': 'WLCL3',
#                    'raw': '"WLCL3"'}},
#                  'right': {'type': 'BinaryExpression',
#                   'operator': '===',
#                   'left': {'type': 'CallExpression',
#                    'callee': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'MemberExpression',
#                      'computed': False,
#                      'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                      'property': {'type': 'Identifier', 'name': 'type'}},
#                     'property': {'type': 'Identifier', 'name': 'slice'}},
#                    'arguments': [{'type': 'UnaryExpression',
#                      'prefix': True,
#                      'operator': '-',
#                      'argument': {'type': 'Literal',
#                       'value': 88,
#                       'raw': '88'}}]},
#                   'right': {'type': 'Literal',
#                    'value': '7EGNO',
#                    'raw': '"7EGNO"'}}},
#                 'right': {'type': 'LogicalExpression',
#                  'operator': '&&',
#                  'left': {'type': 'BinaryExpression',
#                   'operator': '===',
#                   'left': {'type': 'MemberExpression',
#                    'computed': False,
#                    'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                    'property': {'type': 'Identifier', 'name': 'type'}},
#                   'right': {'type': 'Literal',
#                    'value': '6SXZX',
#                    'raw': '"6SXZX"'}},
#                  'right': {'type': 'LogicalExpression',
#                   'operator': '||',
#                   'left': {'type': 'BinaryExpression',
#                    'operator': '===',
#                    'left': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#                     'property': {'type': 'Identifier', 'name': 'length'}},
#                    'right': {'type': 'Literal', 'value': 28, 'raw': '28'}},
#                   'right': {'type': 'BinaryExpression',
#                    'operator': '!==',
#                    'left': {'type': 'MemberExpression',
#                     'computed': False,
#                     'object': {'type': 'MemberExpression',
#                      'computed': True,
#                      'object': {'type': 'Identifier', 'name': 'I13JL7LDGHS'},
#                      'property': {'type': 'Literal',
#                       'value': 56,
#                       'raw': '56'}},
#                     'property': {'type': 'Identifier', 'name': 'type'}},
#                    'right': {'type': 'Literal',
#                     'value': 'CDZ24',
#                     'raw': '"CDZ24"'}}}}},
#                'right': {'type': 'BinaryExpression',
#                 'operator': '===',
#                 'left': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                  'property': {'type': 'Identifier', 'name': 'type'}},
#                 'right': {'type': 'Literal',
#                  'value': 'Z2QNK',
#                  'raw': '"Z2QNK"'}}}}]},
#            {'type': 'SwitchCase',
#             'test': {'type': 'Literal', 'value': 'XDAO3', 'raw': '"XDAO3"'},
#             'consequent': [{'type': 'ReturnStatement',
#               'argument': {'type': 'LogicalExpression',
#                'operator': '||',
#                'left': {'type': 'BinaryExpression',
#                 'operator': '===',
#                 'left': {'type': 'CallExpression',
#                  'callee': {'type': 'MemberExpression',
#                   'computed': False,
#                   'object': {'type': 'MemberExpression',
#                    'computed': False,
#                    'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                    'property': {'type': 'Identifier', 'name': 'type'}},
#                   'property': {'type': 'Identifier', 'name': 'slice'}},
#                  'arguments': [{'type': 'Literal', 'value': 84, 'raw': '84'},
#                   {'type': 'Literal', 'value': 35, 'raw': '35'}]},
#                 'right': {'type': 'Literal',
#                  'value': 'GQH79',
#                  'raw': '"GQH79"'}},
#                'right': {'type': 'BinaryExpression',
#                 'operator': '===',
#                 'left': {'type': 'MemberExpression',
#                  'computed': False,
#                  'object': {'type': 'Identifier', 'name': 'I6OWV3GP6YE'},
#                  'property': {'type': 'Identifier', 'name': 'type'}},
#                 'right': {'type': 'Literal',
#                  'value': 'BWGVB',
#                  'raw': '"BWGVB"'}}}}]}]},
#          {'type': 'ThrowStatement',
#           'argument': {'type': 'NewExpression',
#            'callee': {'type': 'Identifier', 'name': 'IIV9NTJXNJN'},
#            'arguments': [{'type': 'BinaryExpression',
#              'operator': '+',
#              'left': {'type': 'Literal', 'value': 'TESO0', 'raw': '"TESO0"'},
#              'right': {'type': 'MemberExpression',
#               'computed': False,
#               'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#               'property': {'type': 'Identifier', 'name': 'name'}}}]}}]}]},
#      {'type': 'ThrowStatement',
#       'argument': {'type': 'NewExpression',
#        'callee': {'type': 'Identifier', 'name': 'IIV9NTJXNJN'},
#        'arguments': [{'type': 'BinaryExpression',
#          'operator': '+',
#          'left': {'type': 'Literal', 'value': 'R46UI', 'raw': '"R46UI"'},
#          'right': {'type': 'MemberExpression',
#           'computed': False,
#           'object': {'type': 'Identifier', 'name': 'I9R6V4O2430'},
#           'property': {'type': 'Identifier', 'name': 'type'}}}]}}]},
#    'generator': False}],
#  'sourceType': 'script'}

# %% [markdown]
# # function test(){
#
# # var i=5;
# # return i;
# # }
#
# # for (j=0;j<5;j++){
# # i++;
# # }

# %%
inDict = {
    "type": "Program",
    "body": [
        {
            "type": "FunctionDeclaration",
            "id": {
                "type": "Identifier",
                "name": "test"
            },
            "params": [],
            "body": {
                "type": "BlockStatement",
                "body": [
                    {
                        "type": "VariableDeclaration",
                        "declarations": [
                            {
                                "type": "VariableDeclarator",
                                "id": {
                                    "type": "Identifier",
                                    "name": "i"
                                },
                                "init": {
                                    "type": "Literal",
                                    "value": 5,
                                    "raw": "5"
                                }
                            }
                        ],
                        "kind": "var"
                    },
                    {
                        "type": "ReturnStatement",
                        "argument": {
                            "type": "Identifier",
                            "name": "i"
                        }
                    }
                ]
            },
            "generator": False,
            "expression": False,
            "async": False
        },
        {
            "type": "ForStatement",
            "init": {
                "type": "AssignmentExpression",
                "operator": "=",
                "left": {
                    "type": "Identifier",
                    "name": "j"
                },
                "right": {
                    "type": "Literal",
                    "value": 0,
                    "raw": "0"
                }
            },
            "test": {
                "type": "BinaryExpression",
                "operator": "<",
                "left": {
                    "type": "Identifier",
                    "name": "j"
                },
                "right": {
                    "type": "Literal",
                    "value": 5,
                    "raw": "5"
                }
            },
            "update": {
                "type": "UpdateExpression",
                "operator": "++",
                "argument": {
                    "type": "Identifier",
                    "name": "j"
                },
                "prefix": False
            },
            "body": {
                "type": "BlockStatement",
                "body": [
                    {
                        "type": "ExpressionStatement",
                        "expression": {
                            "type": "UpdateExpression",
                            "operator": "++",
                            "argument": {
                                "type": "Identifier",
                                "name": "i"
                            },
                            "prefix": False
                        }
                    }
                ]
            }
        }
    ],
    "sourceType": "script"
}

# %% [markdown]
# ## 1- get template

# %%
t = jt.convert_template(inDict)
t
# Out:
# {'type': 'Program',
#  'body': [{'type': 'FunctionDeclaration',
#    'id': {'type': 'Identifier', 'name': 'test'},
#    'params': [],
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'VariableDeclaration',
#       'declarations': [{'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'IJLN0YE0Y48'},
#         'init': {'type': 'Literal',
#          'value': "<class 'int'>",
#          'raw': "<class 'int'>"}}],
#       'kind': 'var'},
#      {'type': 'ReturnStatement',
#       'argument': {'type': 'Identifier', 'name': 'IJLN0YE0Y48'}}]},
#    'generator': False,
#    'expression': False,
#    'async': False},
#   {'type': 'ForStatement',
#    'init': {'type': 'AssignmentExpression',
#     'operator': '=',
#     'left': {'type': 'Identifier', 'name': 'IEOATYOKZQ5'},
#     'right': {'type': 'Literal',
#      'value': "<class 'int'>",
#      'raw': "<class 'int'>"}},
#    'test': {'type': 'BinaryExpression',
#     'operator': '<',
#     'left': {'type': 'Identifier', 'name': 'IEOATYOKZQ5'},
#     'right': {'type': 'Literal',
#      'value': "<class 'int'>",
#      'raw': "<class 'int'>"}},
#    'update': {'type': 'UpdateExpression',
#     'operator': '++',
#     'argument': {'type': 'Identifier', 'name': 'IEOATYOKZQ5'},
#     'prefix': False},
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'ExpressionStatement',
#       'expression': {'type': 'UpdateExpression',
#        'operator': '++',
#        'argument': {'type': 'Identifier', 'name': 'IJLN0YE0Y48'},
#        'prefix': False}}]}}],
#  'sourceType': 'script'}

# %% [markdown]
# ## 2- generate random variable names and values

# %%
jt.generate_ast_template(t)
# Out:
# {'type': 'Program',
#  'body': [{'type': 'FunctionDeclaration',
#    'id': {'type': 'Identifier', 'name': 'test'},
#    'params': [],
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'VariableDeclaration',
#       'declarations': [{'type': 'VariableDeclarator',
#         'id': {'type': 'Identifier', 'name': 'IB0VPS13G9C'},
#         'init': {'type': 'Literal', 'value': 44, 'raw': '44'}}],
#       'kind': 'var'},
#      {'type': 'ReturnStatement',
#       'argument': {'type': 'Identifier', 'name': 'IB0VPS13G9C'}}]},
#    'generator': False,
#    'expression': False,
#    'async': False},
#   {'type': 'ForStatement',
#    'init': {'type': 'AssignmentExpression',
#     'operator': '=',
#     'left': {'type': 'Identifier', 'name': 'I3KCUHP0CNT'},
#     'right': {'type': 'Literal', 'value': 1, 'raw': '1'}},
#    'test': {'type': 'BinaryExpression',
#     'operator': '<',
#     'left': {'type': 'Identifier', 'name': 'I3KCUHP0CNT'},
#     'right': {'type': 'Literal', 'value': 71, 'raw': '71'}},
#    'update': {'type': 'UpdateExpression',
#     'operator': '++',
#     'argument': {'type': 'Identifier', 'name': 'I3KCUHP0CNT'},
#     'prefix': False},
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'ExpressionStatement',
#       'expression': {'type': 'UpdateExpression',
#        'operator': '++',
#        'argument': {'type': 'Identifier', 'name': 'IB0VPS13G9C'},
#        'prefix': False}}]}}],
#  'sourceType': 'script'}

# %% [markdown]
# ## 3- change blocks of code

# %%
jt.generate_ast_template(jt.generate_random_program(t))
# Out:
# {'type': 'Program',
#  'body': [{'type': 'FunctionDeclaration',
#    'expression': False,
#    'async': False,
#    'id': {'type': 'Identifier', 'name': 'ICQG04ZD2FJ'},
#    'params': [{'type': 'Identifier', 'name': 'event'}],
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'ExpressionStatement',
#       'expression': {'type': 'AssignmentExpression',
#        'operator': '=',
#        'left': {'type': 'Identifier', 'name': 'I0NAO78W0MN'},
#        'right': {'type': 'BinaryExpression',
#         'operator': '/',
#         'left': {'type': 'MemberExpression',
#          'computed': False,
#          'object': {'type': 'Identifier', 'name': 'IYHEHX5MGTK'},
#          'property': {'type': 'Identifier', 'name': 'I78KE55TMUL'}},
#         'right': {'type': 'MemberExpression',
#          'computed': False,
#          'object': {'type': 'Identifier', 'name': 'IYHEHX5MGTK'},
#          'property': {'type': 'Identifier', 'name': 'I42U8066K34'}}}}},
#      {'type': 'ExpressionStatement',
#       'expression': {'type': 'AssignmentExpression',
#        'operator': '=',
#        'left': {'type': 'Identifier', 'name': 'I0NAO78W0MN'},
#        'right': {'type': 'CallExpression',
#         'callee': {'type': 'MemberExpression',
#          'computed': False,
#          'object': {'type': 'Identifier', 'name': 'Math'},
#          'property': {'type': 'Identifier', 'name': 'max'}},
#         'arguments': [{'type': 'Literal', 'value': 96, 'raw': '96'},
#          {'type': 'CallExpression',
#           'callee': {'type': 'MemberExpression',
#            'computed': False,
#            'object': {'type': 'Identifier', 'name': 'Math'},
#            'property': {'type': 'Identifier', 'name': 'min'}},
#           'arguments': [{'type': 'Literal', 'value': 76, 'raw': '76'},
#            {'type': 'Identifier', 'name': 'I0NAO78W0MN'}]}]}}},
#      {'type': 'ExpressionStatement',
#       'expression': {'type': 'CallExpression',
#        'callee': {'type': 'Identifier', 'name': 'ITOHWWUEB91'},
#        'arguments': []}}]},
#    'generator': False},
#   {'type': 'ForStatement',
#    'init': {'type': 'VariableDeclaration',
#     'declarations': [{'type': 'VariableDeclarator',
#       'id': {'type': 'Identifier', 'name': 'IWW7BY0TH4H'},
#       'init': {'type': 'Literal', 'value': 4, 'raw': '4'}}],
#     'kind': 'var'},
#    'test': {'type': 'BinaryExpression',
#     'operator': '<',
#     'left': {'type': 'Identifier', 'name': 'IWW7BY0TH4H'},
#     'right': {'type': 'BinaryExpression',
#      'operator': '-',
#      'left': {'type': 'MemberExpression',
#       'computed': False,
#       'object': {'type': 'Identifier', 'name': 'IL97U79O5KW'},
#       'property': {'type': 'Identifier', 'name': 'length'}},
#      'right': {'type': 'Identifier', 'name': 'IO055DCUCBQ'}}},
#    'update': {'type': 'UpdateExpression',
#     'operator': '++',
#     'argument': {'type': 'Identifier', 'name': 'IWW7BY0TH4H'},
#     'prefix': False},
#    'body': {'type': 'BlockStatement',
#     'body': [{'type': 'ExpressionStatement',
#       'expression': {'type': 'AssignmentExpression',
#        'operator': '=',
#        'left': {'type': 'MemberExpression',
#         'computed': True,
#         'object': {'type': 'MemberExpression',
#          'computed': False,
#          'object': {'type': 'ThisExpression'},
#          'property': {'type': 'Identifier', 'name': 'IL97U79O5KW'}},
#         'property': {'type': 'Identifier', 'name': 'IWW7BY0TH4H'}},
#        'right': {'type': 'MemberExpression',
#         'computed': True,
#         'object': {'type': 'Identifier', 'name': 'IL97U79O5KW'},
#         'property': {'type': 'BinaryExpression',
#          'operator': '+',
#          'left': {'type': 'Identifier', 'name': 'IWW7BY0TH4H'},
#          'right': {'type': 'Identifier', 'name': 'IO055DCUCBQ'}}}}}]}}],
#  'sourceType': 'script'}

# %% [markdown]
# # var e = document.getElementById("myForm");

# %%
inDict = {
    "type": "Program",
    "body": [
        {
            "type": "VariableDeclaration",
            "declarations": [
                {
                    "type": "VariableDeclarator",
                    "id": {
                        "type": "Identifier",
                        "name": "e"
                    },
                    "init": {
                        "type": "CallExpression",
                        "callee": {
                            "type": "MemberExpression",
                            "computed": False,
                            "object": {
                                "type": "Identifier",
                                "name": "document"
                            },
                            "property": {
                                "type": "Identifier",
                                "name": "getElementById"
                            }
                        },
                        "arguments": [
                            {
                                "type": "Literal",
                                "value": "myForm",
                                "raw": "\"myForm\""
                            }
                        ]
                    }
                }
            ],
            "kind": "var"
        }
    ],
    "sourceType": "script"
}

# %% [markdown]
# ## 1- get template

# %%
t = jt.convert_template(inDict)
t
# Out:
# {'type': 'Program',
#  'body': [{'type': 'VariableDeclaration',
#    'declarations': [{'type': 'VariableDeclarator',
#      'id': {'type': 'Identifier', 'name': 'IJB5QUEZA64'},
#      'init': {'type': 'CallExpression',
#       'callee': {'type': 'MemberExpression',
#        'computed': False,
#        'object': {'type': 'Identifier', 'name': 'document'},
#        'property': {'type': 'Identifier', 'name': 'getElementById'}},
#       'arguments': [{'type': 'Literal',
#         'value': "<class 'str'>",
#         'raw': "<class 'str'>"}]}}],
#    'kind': 'var'}],
#  'sourceType': 'script'}

# %% [markdown]
# ## 2- generate random variable names and values

# %%
jt.generate_ast_template(t)
# Out:
# {'type': 'Program',
#  'body': [{'type': 'VariableDeclaration',
#    'declarations': [{'type': 'VariableDeclarator',
#      'id': {'type': 'Identifier', 'name': 'IJH4FMBAP3C'},
#      'init': {'type': 'CallExpression',
#       'callee': {'type': 'MemberExpression',
#        'computed': False,
#        'object': {'type': 'Identifier', 'name': 'document'},
#        'property': {'type': 'Identifier', 'name': 'getElementById'}},
#       'arguments': [{'type': 'Literal',
#         'value': 'AHWM4',
#         'raw': '"AHWM4"'}]}}],
#    'kind': 'var'}],
#  'sourceType': 'script'}

# %% [markdown]
# ## 3- change blocks of code

# %%
jt.generate_ast_template(jt.generate_random_program(t))
# Out:
# {'type': 'Program',
#  'body': [{'type': 'VariableDeclaration',
#    'declarations': [{'type': 'VariableDeclarator',
#      'id': {'type': 'Identifier', 'name': 'IV8CY4EGFRU'},
#      'init': {'type': 'AwaitExpression',
#       'argument': {'type': 'CallExpression',
#        'callee': {'type': 'MemberExpression',
#         'computed': False,
#         'object': {'type': 'MemberExpression',
#          'computed': False,
#          'object': {'type': 'Identifier', 'name': 'IUHHOJ9YCW2'},
#          'property': {'type': 'Identifier', 'name': 'I9OPNCQJ105'}},
#         'property': {'type': 'Identifier', 'name': 'IV8CY4EGFRU'}},
#        'arguments': []}}}],
#    'kind': 'const'}],
#  'sourceType': 'script'}
